# %%
# importing pandas
import pandas as pd

# %%
# Read in all_infectious_disease csv, created in "mortality starter code"
all_infectious_disease = pd.read_csv("all_infectious_disease.csv")
all_infectious_disease_df = pd.DataFrame(all_infectious_disease)
all_infectious_disease_df.head()
# Out:
#    Unnamed: 0 Region Code                Region Name Country Code  \
# 0           9         CSA  Central and South America          ARG
# 1          10         CSA  Central and South America          ARG
# 2          11         CSA  Central and South America          ARG
# 3          12         CSA  Central and South America          ARG
# 4          13         CSA  Central and South America          ARG
#
#   Country Name  Year  Sex Age group code Age Group   Number  \
# 0    Argentina  2011  All        Age_all       All  14572.0
# 1    Argentina  2012  All        Age_all       All  13986.0
# 2    Argentina  2013  All        Age_all       All  14654.0
# 3    Argentina  2014  All        Age_all       All  14816.0
# 4    Argentina  2020  All        Age_all       All  13267.0
#
#    Percentage of cause-specific deaths out of total deaths  \
# 0                                           4.600982
# 1                                           4.409984
# ...
