# %%
# import libraries
import pandas as pd

# %%
# read in csv files

mortality_df = pd.read_csv('data/all_infectious_disease.csv', index_col=0)
expenditures_df = pd.read_csv('data/expenditures.csv')

# %%
# preview mortality data

mortality_df.head()
# Out:
#    Region Code                Region Name Country Code Country Name  Year  \
# 9          CSA  Central and South America          ARG    Argentina  2011
# 10         CSA  Central and South America          ARG    Argentina  2012
# 11         CSA  Central and South America          ARG    Argentina  2013
# 12         CSA  Central and South America          ARG    Argentina  2014
# 13         CSA  Central and South America          ARG    Argentina  2020
#
#     Sex Age group code Age Group   Number  \
# 9   All        Age_all       All  14572.0
# 10  All        Age_all       All  13986.0
# 11  All        Age_all       All  14654.0
# 12  All        Age_all       All  14816.0
# 13  All        Age_all       All  13267.0
#
#     Percentage of cause-specific deaths out of total deaths  \
# 9                                            4.600982
# 10                                           4.409984
# 11                                           4.532254
# 12                                           4.600742
# 13                                           3.526403
#
#     Age-standardized death rate per 100 000 standard population  \
# 9                                           28.986910
# 10                                          27.442447
# 11                                          28.102552
# 12                                          27.769779
# 13                                          22.155131
#
#     Death rate per 100 000 population
# 9                           35.265788
# 10                          33.495233
# 11                          34.728386
# 12                          34.748745
# 13                          29.354514

# %%
# replace space with '_' so that SQL can read the columns
mortality_df.columns = mortality_df.columns.str.replace(' ','_')
mortality_df = mortality_df.\
rename(columns={'Percentage_of_cause-specific_deaths_out_of_total_deaths':'Percent_of_Total',
                'Age-standardized_death_rate_per_100_000_standard_population':'Age_Stnd_Per_100k',
                'Death_rate_per_100_000_population':'Death_rate_per_100k'
                                           })
mortality_df.head()
# Out:
#    Region_Code                Region_Name Country_Code Country_Name  Year  \
# 9          CSA  Central and South America          ARG    Argentina  2011
# 10         CSA  Central and South America          ARG    Argentina  2012
# 11         CSA  Central and South America          ARG    Argentina  2013
# 12         CSA  Central and South America          ARG    Argentina  2014
# 13         CSA  Central and South America          ARG    Argentina  2020
#
#     Sex Age_group_code Age_Group   Number  Percent_of_Total  \
# 9   All        Age_all       All  14572.0          4.600982
# 10  All        Age_all       All  13986.0          4.409984
# 11  All        Age_all       All  14654.0          4.532254
# 12  All        Age_all       All  14816.0          4.600742
# 13  All        Age_all       All  13267.0          3.526403
#
#     Age_Stnd_Per_100k  Death_rate_per_100k
# 9           28.986910            35.265788
# 10          27.442447            33.495233
# 11          28.102552            34.728386
# 12          27.769779            34.748745
# 13          22.155131            29.354514

# %%
# export to csv and reread csv file to see if everything exported correctly

mortality_df.to_csv('data/clean_infectious_disease.csv', index=False)

mort_df = pd.read_csv('data/clean_infectious_disease.csv')
mort_df
# Out:
#     Region_Code                Region_Name Country_Code Country_Name  Year  \
# 0           CSA  Central and South America          ARG    Argentina  2011
# 1           CSA  Central and South America          ARG    Argentina  2012
# 2           CSA  Central and South America          ARG    Argentina  2013
# 3           CSA  Central and South America          ARG    Argentina  2014
# 4           CSA  Central and South America          ARG    Argentina  2020
# ..          ...                        ...          ...          ...   ...
# 836          AS                       Asia          QAT        Qatar  2014
# 837          AS                       Asia          QAT        Qatar  2013
# 838          AS                       Asia          QAT        Qatar  2012
# 839          AS                       Asia          QAT        Qatar  2011
# 840          AS                       Asia          QAT        Qatar  2010
#
#      Sex Age_group_code Age_Group   Number  Percent_of_Total  \
# 0    All        Age_all       All  14572.0          4.600982
# 1    All        Age_all       All  13986.0          4.409984
# 2    All        Age_all       All  14654.0          4.532254
# 3    All        Age_all       All  14816.0          4.600742
# 4    All        Age_all       All  13267.0          3.526403
# ..   ...            ...       ...      ...               ...
# 836  All        Age_all       All     47.0          1.986475
# 837  All        Age_all       All     34.0          1.593999
# 838  All        Age_all       All     26.0          1.280158
# 839  All        Age_all       All     27.0          1.385326
# 840  All        Age_all       All     32.0          1.624365
#
#      Age_Stnd_Per_100k  Death_rate_per_100k
# 0            28.986910            35.265788
# 1            27.442447            33.495233
# 2            28.102552            34.728386
# 3            27.769779            34.748745
# 4            22.155131            29.354514
# ..                 ...                  ...
# 836           7.086269             1.911192
# 837           4.570641             1.455122
# 838           5.143695             1.183931
# 839           5.888129             1.326214
# 840          12.462967             1.723834
#
# [841 rows x 12 columns]

# %%
expenditures_df.head()
# Out:
#    country code region        income  year  che_gdp(%)  hk_gdp(%) che_pc_usd  \
# 0  Algeria  DZA    AFR  Lower-middle  2015         7.0        0.0        292
# 1    Benin  BEN    AFR  Lower-middle  2010         3.0        0.4         30
# 2    Benin  BEN    AFR  Lower-middle  2011         3.0        0.1         33
# 3    Benin  BEN    AFR  Lower-middle  2012         3.1        0.3         34
# 4    Benin  BEN    AFR  Lower-middle  2013         2.9        0.2         35
#
#          che gdp_pc_usd che_usd
# 0  1,163,740      4,197  11,557
# 1    142,008      1,009     287
# 2    151,029      1,099     320
# 3    174,951      1,113     343
# 4    177,366      1,214     359

# %%
# join tables

# exp_mort_merge = expenditures_df.merge(mortality_df, how='inner', on=['Country Name','Year'
#                                                                       ])
# exp_mort_merge = exp_mort_merge.dropna()

# exp_mort_merge = exp_mort_merge.\
# loc[exp_mort_merge['Age group code']=='Age_all', :]

# exp_mort_merge = exp_mort_merge.drop(columns=['Region Code_y', 'Country Code_y'])
# exp_mort_merge = exp_mort_merge.rename(columns={'Country Code_x': 'Country Code',
#                               'Region Code_x': 'Region Code'})
# exp_mort_merge = exp_mort_merge.loc[exp_mort_merge['Sex']=='All',:]
# exp_mort_merge.info()
