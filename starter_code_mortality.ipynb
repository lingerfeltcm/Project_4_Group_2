# %%
# importing pandas to clean
import pandas as pd

# %%
# Read in infectious disease data
all_infectious_disease_data = pd.read_csv(r"Data\WHOMortalityDatabase_Deaths_Infectious and parasitic diseases_6th May 2024 20_00.csv", skiprows=[0,1,2,3,4,5], index_col = False)
all_infectious_disease_df = pd.DataFrame(all_infectious_disease_data)
all_infectious_disease_df.head()
# Out:
#   Region Code Region Name Country Code Country Name  Year  Sex Age group code  \
# 0          EU      Europe          ALB      Albania  1987  All    Age_unknown
# 1          EU      Europe          ALB      Albania  1987  All     Age85_over
# 2          EU      Europe          ALB      Albania  1987  All       Age80_84
# 3          EU      Europe          ALB      Albania  1987  All       Age75_79
# 4          EU      Europe          ALB      Albania  1987  All       Age70_74
#
#    Age Group  Number  Percentage of cause-specific deaths out of total deaths  \
# 0  [Unknown]     0.0                                                NaN
# 1      [85+]    14.0                                           0.628931
# 2    [80-84]     6.0                                           0.366077
# 3    [75-79]    15.0                                           0.709220
# 4    [70-74]    13.0                                           0.719823
#
#    Age-standardized death rate per 100 000 standard population  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Death rate per 100 000 population
# 0                                NaN
# 1                         140.000000
# 2                          36.144578
# 3                          48.701299
# 4                          31.862745

# %%
# limit data range to years 2010 or later, all age groups, and all sexes
all_infectious_disease_df = all_infectious_disease_df.drop(all_infectious_disease_df[all_infectious_disease_df['Year'] < 2010].index)
all_infectious_disease_df = all_infectious_disease_df.drop(all_infectious_disease_df[all_infectious_disease_df['Age group code']!='Age_all'].index)
all_infectious_disease_df = all_infectious_disease_df.drop(all_infectious_disease_df[all_infectious_disease_df['Sex']!='All'].index)

# %%
# drop null data
all_infectious_disease_df = all_infectious_disease_df.dropna()

# %%
# check if dataset has enough data for project
all_infectious_disease_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1082 entries, 1323 to 309519
# Data columns (total 12 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Region Code                                                  1082 non-null   object
#  1   Region Name                                                  1082 non-null   object
#  2   Country Code                                                 1082 non-null   object
#  3   Country Name                                                 1082 non-null   object
#  4   Year                                                         1082 non-null   int64
#  5   Sex                                                          1082 non-null   object
#  6   Age group code                                               1082 non-null   object
#  7   Age Group                                                    1082 non-null   object
#  8   Number                                                       1082 non-null   float64
#  9   Percentage of cause-specific deaths out of total deaths      1082 non-null   float64
#  10  Age-standardized death rate per 100 000 standard population  1082 non-null   float64
#  11  Death rate per 100 000 population                            1082 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 109.9+ KB

# %%
# remove brackets from Age Group column
all_infectious_disease_df['Age Group'] = all_infectious_disease_df['Age Group'].str.strip('[]').astype(str)

# %%
# look at data head
all_infectious_disease_df.head()
# Out:
#      Region Code                      Region Name Country Code  \
# 1323          EU                           Europe          ALB
# 3841         NAC  North America and the Caribbean          ATG
# 3904         NAC  North America and the Caribbean          ATG
# 3967         NAC  North America and the Caribbean          ATG
# 6700         CSA        Central and South America          ARG
#
#              Country Name  Year  Sex Age group code Age Group   Number  \
# 1323              Albania  2010  All        Age_all       All     40.0
# 3841  Antigua and Barbuda  2012  All        Age_all       All     35.0
# 3904  Antigua and Barbuda  2013  All        Age_all       All     28.0
# 3967  Antigua and Barbuda  2014  All        Age_all       All     40.0
# 6700            Argentina  2010  All        Age_all       All  14684.0
#
#       Percentage of cause-specific deaths out of total deaths  \
# 1323                                           0.329516
# 3841                                           7.099391
# 3904                                           5.944798
# 3967                                           6.896552
# 6700                                           4.642457
#
#       Age-standardized death rate per 100 000 standard population  \
# 1323                                           1.289031
# 3841                                          37.839414
# 3904                                          29.327673
# 3967                                          40.583518
# 6700                                          29.704645
#
#       Death rate per 100 000 population
# 1323                           1.373141
# 3841                          38.712960
# 3904                          30.595743
# 3967                          43.214278
# 6700                          35.905930

# %%
#locate number of unique country names to identify how many we can drop.
country_count = all_infectious_disease_df['Country Name'].nunique()
print(country_count)
# Out:
# 115

# %%
# identify the number of countries with less than 10 years worth of data
year_counts = all_infectious_disease_df.groupby('Country Name').count()['Year'].sort_values()
print(year_counts[0:43])
# Out:
# Country Name
# Albania                                1
# Syrian Arab Republic                   1
# Cabo Verde                             1
# Tajikistan                             2
# Saudi Arabia                           2
# Montenegro                             2
# Iraq                                   2
# Fiji                                   2
# United Arab Emirates                   3
# Trinidad and Tobago                    3
# Lebanon                                3
# Barbados                               4
# Iran (Islamic Republic of)             5
# Suriname                               5
# Bahrain                                5
# Jamaica                                5
# Belarus                                5
# Mayotte                                5
# Martinique                             6
# Mongolia                               6
# Bahamas                                6
# Turkmenistan                           6
# New Zealand                            7
# Norway                                 7
# Philippines                            7
# Jordan                                 7
# R?union                                7
# Sri Lanka                              7
# Guadeloupe                             7
# French Guiana                          7
# Belize                                 7
# Venezuela (Bolivarian Republic of)     7
# Oman                                   8
# China, Hong Kong SAR                   8
# Ukraine                                8
# Puerto Rico                            9
# Republic of Moldova                    9
# Dominican Republic                     9
# South Africa                           9
# El Salvador                            9
# Bosnia and Herzegovina                 9
# Maldives                              10
# Kyrgyzstan                            10
# Name: Year, dtype: int64

# %%
# create a data fram that merges the original data frame with the new year_counts without losing data
output_df = all_infectious_disease_df.merge(year_counts, on="Country Name")

# %%
# check for success
output_df.head()
# Out:
#   Region Code                      Region Name Country Code  \
# 0         NAC  North America and the Caribbean          ATG
# 1         NAC  North America and the Caribbean          ATG
# 2         NAC  North America and the Caribbean          ATG
# 3         NAC  North America and the Caribbean          ATG
# 4         NAC  North America and the Caribbean          ATG
#
#           Country Name  Year_x  Sex Age group code Age Group  Number  \
# 0  Antigua and Barbuda    2012  All        Age_all       All    35.0
# 1  Antigua and Barbuda    2013  All        Age_all       All    28.0
# 2  Antigua and Barbuda    2014  All        Age_all       All    40.0
# 3  Antigua and Barbuda    2020  All        Age_all       All    26.0
# 4  Antigua and Barbuda    2019  All        Age_all       All    24.0
#
#    Percentage of cause-specific deaths out of total deaths  \
# 0                                           7.099391
# 1                                           5.944798
# 2                                           6.896552
# 3                                           4.529617
# 4                                           3.883495
#
#    Age-standardized death rate per 100 000 standard population  \
# 0                                          37.839414
# 1                                          29.327673
# 2                                          40.583518
# 3                                          24.842839
# 4                                          22.730870
#
#    Death rate per 100 000 population  Year_y
# 0                          38.712960       9
# 1                          30.595743       9
# 2                          43.214278       9
# 3                          26.549847       9
# 4                          24.712206       9

# %%
# drop all instances where a country's year count is less than 10
all_infectious_disease_df = output_df.drop(output_df[output_df['Year_y'] < 10].index)

# %%
# delete the now unneeded Year_y column
del all_infectious_disease_df['Year_y']

# %%
# check for success
all_infectious_disease_df.head()
# Out:
#    Region Code                Region Name Country Code Country Name  Year_x  \
# 9          CSA  Central and South America          ARG    Argentina    2011
# 10         CSA  Central and South America          ARG    Argentina    2012
# 11         CSA  Central and South America          ARG    Argentina    2013
# 12         CSA  Central and South America          ARG    Argentina    2014
# 13         CSA  Central and South America          ARG    Argentina    2020
#
#     Sex Age group code Age Group   Number  \
# 9   All        Age_all       All  14572.0
# 10  All        Age_all       All  13986.0
# 11  All        Age_all       All  14654.0
# 12  All        Age_all       All  14816.0
# 13  All        Age_all       All  13267.0
#
#     Percentage of cause-specific deaths out of total deaths  \
# 9                                            4.600982
# 10                                           4.409984
# 11                                           4.532254
# 12                                           4.600742
# 13                                           3.526403
#
#     Age-standardized death rate per 100 000 standard population  \
# 9                                           28.986910
# 10                                          27.442447
# 11                                          28.102552
# 12                                          27.769779
# 13                                          22.155131
#
#     Death rate per 100 000 population
# 9                           35.265788
# 10                          33.495233
# 11                          34.728386
# 12                          34.748745
# 13                          29.354514

# %%
# rename Year_x column
all_infectious_disease_df= all_infectious_disease_df.rename(columns={'Year_x':'Year'})

# %%
# check if this process was successful by sorting year counts by ascending
year_counts = all_infectious_disease_df.groupby('Country Name').count()['Year'].sort_values()
print(year_counts[0:43])
# Out:
# Country Name
# Kyrgyzstan                                              10
# Thailand                                                10
# T?rkiye                                                 10
# Slovakia                                                10
# Russian Federation                                      10
# Romania                                                 10
# Portugal                                                10
# Maldives                                                10
# Uruguay                                                 10
# Kuwait                                                  10
# Guyana                                                  10
# Egypt                                                   10
# Uzbekistan                                              10
# Brunei Darussalam                                       10
# Malta                                                   11
# United Kingdom of Great Britain and Northern Ireland    11
# Slovenia                                                11
# Seychelles                                              11
# Saint Lucia                                             11
# Belgium                                                 11
# Brazil                                                  11
# Qatar                                                   11
# Peru                                                    11
# Panama                                                  11
# North Macedonia                                         11
# Malaysia                                                11
# Italy                                                   11
# Israel                                                  11
# Ireland                                                 11
# Argentina                                               11
# Greece                                                  11
# France                                                  11
# Costa Rica                                              11
# Germany                                                 11
# Paraguay                                                12
# Georgia                                                 12
# Finland                                                 12
# Republic of Korea                                       12
# Ecuador                                                 12
# Poland                                                  12
# Austria                                                 12
# Czechia                                                 12
# Spain                                                   12
# Name: Year, dtype: int64

# %%
# check amount of data left over is sufficient
all_infectious_disease_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 841 entries, 9 to 849
# Data columns (total 12 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Region Code                                                  841 non-null    object
#  1   Region Name                                                  841 non-null    object
#  2   Country Code                                                 841 non-null    object
#  3   Country Name                                                 841 non-null    object
#  4   Year                                                         841 non-null    int64
#  5   Sex                                                          841 non-null    object
#  6   Age group code                                               841 non-null    object
#  7   Age Group                                                    841 non-null    object
#  8   Number                                                       841 non-null    float64
#  9   Percentage of cause-specific deaths out of total deaths      841 non-null    float64
#  10  Age-standardized death rate per 100 000 standard population  841 non-null    float64
#  11  Death rate per 100 000 population                            841 non-null    float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 79.0+ KB

# %%
#export to CSV
all_infectious_disease_df.to_csv('Data/all_infectious_disease.csv')
